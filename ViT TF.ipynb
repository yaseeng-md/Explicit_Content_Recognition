# %%
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.model_selection import train_test_split

import keras
from keras import layers,ops
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
num_classes = 2
input_shape = (224,224, 3)

# (x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

# print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
# print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")

# %%
import pickle
with open("Features/img_data.pkl", "rb") as f:
    image_data = pickle.load(f)
with open ("Features/labels.pkl","rb") as f:
    labels = pickle.load(f)

# %%
first_500_images = image_data[:1500]
last_500_images = image_data[-1500:]
images_subset = np.concatenate([first_500_images,last_500_images],axis = 0)

first_500_labels = labels[:1500]
last_500_labels = labels[-1500:]
labels_subset = np.concatenate([first_500_labels,last_500_labels],axis = 0)
images_subset.shape, labels_subset.shape
# Out:
# ((3000, 224, 224, 3), (3000,))

# %%
x_train, x_val, y_train, y_val = train_test_split(images_subset,labels_subset,test_size = 0.3)
x_train.shape
# Out:
# (2100, 224, 224, 3)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 50  # For real training, use num_epochs=100. 10 is a test value
image_size = 224  # We'll resize input images to this size
patch_size = 16  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 8
mlp_head_units = [
    2048,
    1024,
]

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        input_shape = ops.shape(images)
        batch_size = input_shape[0]
        height = input_shape[1]
        width = input_shape[2]
        channels = input_shape[3]
        num_patches_h = height // self.patch_size
        num_patches_w = width // self.patch_size
        patches = keras.ops.image.extract_patches(images, size=self.patch_size)
        patches = ops.reshape(
            patches,
            (
                batch_size,
                num_patches_h * num_patches_w,
                self.patch_size * self.patch_size * channels,
            ),
        )
        return patches

    def get_config(self):
        config = super().get_config()
        config.update({"patch_size": self.patch_size})
        return config

# %%
plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image)
plt.axis("off")

resized_image = ops.image.resize(
    ops.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = ops.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(ops.convert_to_numpy(patch_img))
    plt.axis("off")
# Out:
# Image size: 224 X 224
# Patch size: 16 X 16
# Patches per image: 196
# Elements per patch: 768

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = ops.expand_dims(
            ops.arange(start=0, stop=self.num_patches, step=1), axis=0
        )
        projected_patches = self.projection(patch)
        encoded = projected_patches + self.position_embedding(positions)
        return encoded

    def get_config(self):
        config = super().get_config()
        config.update({"num_patches": self.num_patches})
        return config

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)

# %%
def create_vit_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data = (x_val,y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_val, y_val)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 74s 5s/step - accuracy: 0.4879 - loss: 12.0531 - top-5-accuracy: 1.0000 - val_accuracy: 0.5011 - val_loss: 1.9092 - val_top-5-accuracy: 1.0000
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.5379 - loss: 2.3535 - top-5-accuracy: 1.0000 - val_accuracy: 0.5011 - val_loss: 1.4470 - val_top-5-accuracy: 1.0000
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step - accuracy: 0.5301 - loss: 1.6864 - top-5-accuracy: 1.0000 - val_accuracy: 0.6256 - val_loss: 0.6341 - val_top-5-accuracy: 1.0000
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.5835 - loss: 0.8792 - top-5-accuracy: 1.0000 - val_accuracy: 0.6322 - val_loss: 0.6513 - val_top-5-accuracy: 1.0000
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - accuracy: 0.6009 - loss: 0.7724 - top-5-accuracy: 1.0000 - val_accuracy: 0.7544 - val_loss: 0.6270 - val_top-5-accuracy: 1.0000
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - accuracy: 0.6467 - loss: 0.6758 - top-5-accuracy: 1.0000 - val_accuracy: 0.7111 - val_loss: 0.6115 - val_top-5-accuracy: 1.0000
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.6330 - loss: 0.6693 - top-5-accuracy: 1.0000 - val_accuracy: 0.7456 - val_loss: 0.6234 - val_top-5-accuracy: 1.0000
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.6282 - loss: 0.6533 - top-5-accuracy: 1.0000 - val_accuracy: 0.7122 - val_loss: 0.6058 - val_top-5-accuracy: 1.0000
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.6610 - loss: 0.6171 - top-5-accuracy: 1.0000 - val_accuracy: 0.7522 - val_loss: 0.5933 - val_top-5-accuracy: 1.0000
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.6574 - loss: 0.6334 - top-5-accuracy: 1.0000 - val_accuracy: 0.7511 - val_loss: 0.5747 - val_top-5-accuracy: 1.0000
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - accuracy: 0.6693 - loss: 0.6025 - top-5-accuracy: 1.0000 - val_accuracy: 0.7356 - val_loss: 0.5675 - val_top-5-accuracy: 1.0000
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.6609 - loss: 0.6295 - top-5-accuracy: 1.0000 - val_accuracy: 0.7467 - val_loss: 0.5305 - val_top-5-accuracy: 1.0000
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.6791 - loss: 0.5983 - top-5-accuracy: 1.0000 - val_accuracy: 0.7478 - val_loss: 0.5307 - val_top-5-accuracy: 1.0000
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - accuracy: 0.6920 - loss: 0.5931 - top-5-accuracy: 1.0000 - val_accuracy: 0.7489 - val_loss: 0.5344 - val_top-5-accuracy: 1.0000
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.6852 - loss: 0.5988 - top-5-accuracy: 1.0000 - val_accuracy: 0.7333 - val_loss: 0.5464 - val_top-5-accuracy: 1.0000
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - accuracy: 0.6875 - loss: 0.6025 - top-5-accuracy: 1.0000 - val_accuracy: 0.7278 - val_loss: 0.5656 - val_top-5-accuracy: 1.0000
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - accuracy: 0.6772 - loss: 0.5899 - top-5-accuracy: 1.0000 - val_accuracy: 0.7589 - val_loss: 0.5266 - val_top-5-accuracy: 1.0000
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7034 - loss: 0.5759 - top-5-accuracy: 1.0000 - val_accuracy: 0.7478 - val_loss: 0.5032 - val_top-5-accuracy: 1.0000
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.7023 - loss: 0.5740 - top-5-accuracy: 1.0000 - val_accuracy: 0.7733 - val_loss: 0.5192 - val_top-5-accuracy: 1.0000
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.7211 - loss: 0.5511 - top-5-accuracy: 1.0000 - val_accuracy: 0.7611 - val_loss: 0.5360 - val_top-5-accuracy: 1.0000
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.7043 - loss: 0.5696 - top-5-accuracy: 1.0000 - val_accuracy: 0.7478 - val_loss: 0.5210 - val_top-5-accuracy: 1.0000
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.7432 - loss: 0.5386 - top-5-accuracy: 1.0000 - val_accuracy: 0.7844 - val_loss: 0.5478 - val_top-5-accuracy: 1.0000
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7096 - loss: 0.5687 - top-5-accuracy: 1.0000 - val_accuracy: 0.7778 - val_loss: 0.5326 - val_top-5-accuracy: 1.0000
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7128 - loss: 0.5454 - top-5-accuracy: 1.0000 - val_accuracy: 0.7433 - val_loss: 0.5373 - val_top-5-accuracy: 1.0000
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7186 - loss: 0.5561 - top-5-accuracy: 1.0000 - val_accuracy: 0.7800 - val_loss: 0.4879 - val_top-5-accuracy: 1.0000
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7560 - loss: 0.5265 - top-5-accuracy: 1.0000 - val_accuracy: 0.7811 - val_loss: 0.4803 - val_top-5-accuracy: 1.0000
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.7447 - loss: 0.5330 - top-5-accuracy: 1.0000 - val_accuracy: 0.7889 - val_loss: 0.4974 - val_top-5-accuracy: 1.0000
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.7487 - loss: 0.5198 - top-5-accuracy: 1.0000 - val_accuracy: 0.7633 - val_loss: 0.5143 - val_top-5-accuracy: 1.0000
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7094 - loss: 0.5595 - top-5-accuracy: 1.0000 - val_accuracy: 0.7867 - val_loss: 0.4900 - val_top-5-accuracy: 1.0000
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7275 - loss: 0.5347 - top-5-accuracy: 1.0000 - val_accuracy: 0.7656 - val_loss: 0.4665 - val_top-5-accuracy: 1.0000
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7252 - loss: 0.5376 - top-5-accuracy: 1.0000 - val_accuracy: 0.7789 - val_loss: 0.4724 - val_top-5-accuracy: 1.0000
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7546 - loss: 0.5150 - top-5-accuracy: 1.0000 - val_accuracy: 0.7700 - val_loss: 0.5094 - val_top-5-accuracy: 1.0000
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step - accuracy: 0.7366 - loss: 0.5189 - top-5-accuracy: 1.0000 - val_accuracy: 0.7889 - val_loss: 0.4945 - val_top-5-accuracy: 1.0000
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7774 - loss: 0.5063 - top-5-accuracy: 1.0000 - val_accuracy: 0.7922 - val_loss: 0.4813 - val_top-5-accuracy: 1.0000
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.7637 - loss: 0.4932 - top-5-accuracy: 1.0000 - val_accuracy: 0.7989 - val_loss: 0.4518 - val_top-5-accuracy: 1.0000
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7591 - loss: 0.5201 - top-5-accuracy: 1.0000 - val_accuracy: 0.7933 - val_loss: 0.4760 - val_top-5-accuracy: 1.0000
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7638 - loss: 0.4972 - top-5-accuracy: 1.0000 - val_accuracy: 0.7833 - val_loss: 0.4943 - val_top-5-accuracy: 1.0000
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7641 - loss: 0.5071 - top-5-accuracy: 1.0000 - val_accuracy: 0.7922 - val_loss: 0.4764 - val_top-5-accuracy: 1.0000
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7609 - loss: 0.5124 - top-5-accuracy: 1.0000 - val_accuracy: 0.7911 - val_loss: 0.4614 - val_top-5-accuracy: 1.0000
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7633 - loss: 0.4899 - top-5-accuracy: 1.0000 - val_accuracy: 0.7756 - val_loss: 0.4914 - val_top-5-accuracy: 1.0000
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7616 - loss: 0.4996 - top-5-accuracy: 1.0000 - val_accuracy: 0.8033 - val_loss: 0.4615 - val_top-5-accuracy: 1.0000
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - accuracy: 0.7581 - loss: 0.4797 - top-5-accuracy: 1.0000 - val_accuracy: 0.7889 - val_loss: 0.4657 - val_top-5-accuracy: 1.0000
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.7593 - loss: 0.5053 - top-5-accuracy: 1.0000 - val_accuracy: 0.8000 - val_loss: 0.4351 - val_top-5-accuracy: 1.0000
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7714 - loss: 0.4972 - top-5-accuracy: 1.0000 - val_accuracy: 0.7956 - val_loss: 0.4732 - val_top-5-accuracy: 1.0000
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7731 - loss: 0.4886 - top-5-accuracy: 1.0000 - val_accuracy: 0.7967 - val_loss: 0.4511 - val_top-5-accuracy: 1.0000
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7902 - loss: 0.4625 - top-5-accuracy: 1.0000 - val_accuracy: 0.7800 - val_loss: 0.4774 - val_top-5-accuracy: 1.0000
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7800 - loss: 0.4663 - top-5-accuracy: 1.0000 - val_accuracy: 0.8189 - val_loss: 0.4469 - val_top-5-accuracy: 1.0000
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.7828 - loss: 0.4744 - top-5-accuracy: 1.0000 - val_accuracy: 0.8056 - val_loss: 0.4519 - val_top-5-accuracy: 1.0000
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.7767 - loss: 0.4690 - top-5-accuracy: 1.0000 - val_accuracy: 0.8144 - val_loss: 0.4456 - val_top-5-accuracy: 1.0000
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.7700 - loss: 0.4882 - top-5-accuracy: 1.0000 - val_accuracy: 0.7911 - val_loss: 0.4751 - val_top-5-accuracy: 1.0000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.8168 - loss: 0.4431 - top-5-accuracy: 1.0000
# Test accuracy: 81.89%
# Test top 5 accuracy: 100.0%

# %%
def plot_history(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()


plot_history("loss")
plot_history("top-5-accuracy")

# %%
plt.plot(history.epoch,history.history["accuracy"],label = "Training")
plt.plot(history.epoch,history.history["val_accuracy"],label = "Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracy Score")
plt.legend()
plt.show()

# %%
plt.plot(history.epoch,history.history["loss"],label = "Training")
plt.plot(history.epoch,history.history["loss"],label = "Validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
